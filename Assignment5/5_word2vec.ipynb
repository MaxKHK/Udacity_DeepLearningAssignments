# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.161867
# Nearest to all: ajaccio, legged, creationism, vagaries, guitarists, penetration, ibero, mactutor,
# Nearest to history: diaeresis, nicolai, canmore, mudslides, harmonize, excerpt, thujone, fried,
# Nearest to from: eclac, texan, subsisting, kramer, arminians, traction, displayed, dissatisfied,
# Nearest to system: arthur, gmt, midair, zug, thicker, pathological, fabricated, kabuki,
# Nearest to or: omnium, condemns, lama, keen, capitulated, participate, removes, aglaulus,
# Nearest to so: venizelos, serialism, hijacking, gadget, dortmund, prepared, deliveries, atlanta,
# Nearest to this: crouching, dice, mona, parenthood, gorey, tyne, andes, brahmins,
# Nearest to three: miniature, subdisciplines, molina, navy, burglary, exerted, bonds, jennifer,
# Nearest to years: ballets, knut, eidyn, cuff, bernard, virility, cruelty, masada,
# Nearest to they: alexandra, taito, aconcagua, barbarians, mutate, occasioned, filmi, lingua,
# Nearest to at: matsui, persuade, purchaser, matteo, hitchhikers, volleyball, alcal, abydos,
# Nearest to will: pancreas, failing, plesiosaur, egress, unicellular, correct, bigg, merges,
# Nearest to often: taliban, obrzeg, hypertrophy, solidified, hwang, airborne, broader, tuple,
# Nearest to four: bottleneck, endorsed, culprit, shaw, guerilla, juliana, curing, chariot,
# Nearest to new: plein, numbers, togo, intelligencer, overseas, releasing, furnishes, downloadable,
# Nearest to there: exploratory, dhimmi, falcon, anatomically, hathor, folio, dsl, armadillos,
# Average loss at step 2000: 4.357379
# Average loss at step 4000: 3.861717
# Average loss at step 6000: 3.786727
# Average loss at step 8000: 3.685138
# Average loss at step 10000: 3.606115
# Nearest to all: guitarists, many, ibero, bambaataa, palliative, booed, outlaws, synagogue,
# Nearest to history: diaeresis, ou, canmore, character, privilege, termites, anti, shrubs,
# Nearest to from: in, with, by, into, of, traction, msp, halved,
# Nearest to system: deepen, arthur, zug, henotheism, column, viet, conventional, thrillers,
# Nearest to or: and, bohr, than, dissociation, deansgate, s, belli, harming,
# Nearest to so: ellefson, wollaston, genovese, venizelos, galleon, breakers, unrivaled, deserve,
# Nearest to this: the, it, which, a, alh, consultancy, its, aides,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to years: bernard, trebizond, cuff, ballets, germania, masada, knut, dealt,
# Nearest to they: he, it, there, griffon, alexandra, she, not, amor,
# Nearest to at: on, dura, matsui, of, in, sopranos, during, castel,
# Nearest to will: must, would, ipc, probate, plesiosaur, unicellular, wir, merges,
# Nearest to often: also, taliban, who, sometimes, what, lomax, commonly, horner,
# Nearest to four: six, eight, three, five, seven, nine, two, zero,
# Nearest to new: fluctuations, painterly, plein, mifune, eluded, unrecorded, astronauts, nther,
# Nearest to there: it, they, he, exploratory, attacks, claims, pett, dsl,
# Average loss at step 12000: 3.604443
# Average loss at step 14000: 3.567429
# Average loss at step 16000: 3.401975
# Average loss at step 18000: 3.460057
# Average loss at step 20000: 3.537684
# Nearest to all: many, these, ibero, guitarists, some, booed, palliative, propagates,
# Nearest to history: ou, character, tompkins, source, shrubs, diaeresis, termites, canmore,
# Nearest to from: in, into, at, with, and, between, by, for,
# Nearest to system: deepen, henotheism, thrillers, cladistics, column, zug, because, laws,
# Nearest to or: and, than, ren, yog, bohr, verdicts, pohjola, cddb,
# Nearest to so: genovese, wollaston, ellefson, deserve, nonverbal, unrivaled, autographed, identified,
# Nearest to this: it, which, the, stanton, aides, alh, ovule, its,
# Nearest to three: four, five, six, seven, two, eight, zero, nine,
# Nearest to years: trebizond, kang, germania, ballets, dealt, masada, schrader, whitfield,
# Nearest to they: he, there, we, it, she, even, not, meo,
# Nearest to at: in, on, turbines, during, from, emilia, after, is,
# Nearest to will: would, must, can, may, to, torsion, could, ipc,
# Nearest to often: also, sometimes, commonly, who, there, less, taliban, what,
# Nearest to four: three, six, eight, seven, five, nine, two, zero,
# Nearest to new: painterly, unrecorded, fluctuations, eluded, tint, dials, catastrophism, tip,
# Nearest to there: they, it, he, which, often, substituted, befriends, still,
# Average loss at step 22000: 3.502957
# Average loss at step 24000: 3.489567
# Average loss at step 26000: 3.479274
# Average loss at step 28000: 3.476678
# Average loss at step 30000: 3.496992
# Nearest to all: many, some, receptions, these, outlaws, guitarists, booed, both,
# Nearest to history: source, tompkins, linden, ou, hectare, termites, character, balliol,
# Nearest to from: into, between, through, in, bukharin, after, by, before,
# Nearest to system: systems, deepen, henotheism, thrillers, cladistics, yster, uk, electron,
# Nearest to or: and, redirection, than, calibers, organelle, harming, prinz, instill,
# Nearest to so: genovese, ellefson, deserve, wollaston, unrivaled, divergent, autographed, grasses,
# Nearest to this: it, which, there, that, stanton, criticizing, any, consultancy,
# Nearest to three: four, five, eight, seven, two, six, nine, zero,
# Nearest to years: days, trebizond, times, kang, germania, ride, year, whitfield,
# Nearest to they: there, we, he, she, it, you, who, not,
# Nearest to at: in, during, after, turbines, noncommercial, on, ripening, when,
# Nearest to will: would, can, must, may, could, wir, torsion, should,
# Nearest to often: sometimes, commonly, also, who, there, widely, what, usually,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to new: painterly, dials, tip, fluctuations, pedersen, kryptonite, second, catastrophism,
# Nearest to there: they, it, he, still, this, often, we, which,
# Average loss at step 32000: 3.502045
# Average loss at step 34000: 3.496069
# Average loss at step 36000: 3.455880
# Average loss at step 38000: 3.300562
# Average loss at step 40000: 3.421795
# Nearest to all: both, every, receptions, many, goering, manchester, silesia, nage,
# Nearest to history: termites, complementary, tompkins, apollodorus, ou, balliol, diaeresis, linden,
# Nearest to from: into, through, in, between, by, modi, aggressors, bukharin,
# Nearest to system: systems, cladistics, deepen, massif, henotheism, derrick, electron, aw,
# Nearest to or: and, than, hijackings, jabbar, arable, ranked, beatrix, calibers,
# Nearest to so: unrivaled, divergent, autographed, occasioned, unpopularity, applications, deserve, grasses,
# Nearest to this: which, that, it, the, some, stanton, criticizing, another,
# Nearest to three: five, four, six, two, seven, eight, nine, one,
# Nearest to years: days, times, trebizond, year, kang, hardened, tokugawa, schrader,
# Nearest to they: we, he, there, you, it, she, i, these,
# Nearest to at: in, during, turbines, on, noncommercial, without, matsui, interrogated,
# Nearest to will: can, would, must, could, may, should, might, torsion,
# Nearest to often: sometimes, usually, also, commonly, generally, widely, who, still,
# Nearest to four: six, five, three, seven, eight, two, nine, one,
# Nearest to new: painterly, pedersen, tint, dials, empiricists, second, tip, huge,
# Nearest to there: they, it, he, now, often, currently, still, we,
# Average loss at step 42000: 3.436017
# Average loss at step 44000: 3.453545
# Average loss at step 46000: 3.449373
# Average loss at step 48000: 3.352349
# Average loss at step 50000: 3.380464
# Nearest to all: both, manchester, these, multiplicative, receptions, expect, every, out,
# Nearest to history: gaye, complementary, termites, hall, apollodorus, period, tompkins, reflex,
# Nearest to from: into, around, in, through, until, under, before, modi,
# Nearest to system: systems, thrillers, aw, electron, cladistics, column, massif, sector,
# Nearest to or: and, than, calibers, ovaries, rip, dunst, adolescents, docile,
# Nearest to so: if, imran, thus, too, autographed, divergent, unrivaled, before,
# Nearest to this: which, it, stanton, the, there, that, philosophie, some,
# Nearest to three: six, seven, four, eight, two, five, nine, zero,
# Nearest to years: days, times, year, months, trebizond, kang, alomari, weeks,
# Nearest to they: he, we, there, she, you, it, crawl, amor,
# Nearest to at: during, turbines, on, in, without, upload, around, demoralized,
# Nearest to will: would, can, must, could, may, should, might, does,
# Nearest to often: sometimes, generally, usually, commonly, widely, frequently, also, now,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to new: huge, painterly, tint, pedersen, dials, second, outback, convenient,
# Nearest to there: they, it, he, now, currently, often, we, she,
# Average loss at step 52000: 3.435554
# Average loss at step 54000: 3.429393
# Average loss at step 56000: 3.436100
# Average loss at step 58000: 3.394172
# Average loss at step 60000: 3.388865
# Nearest to all: both, these, many, those, every, some, any, receptions,
# Nearest to history: complementary, gaye, period, constitution, apollodorus, irwin, termites, affairs,
# Nearest to from: through, into, nominal, modi, ensign, overbeck, bukharin, in,
# Nearest to system: systems, line, thrillers, cladistics, sector, electron, rastafari, proclaimed,
# Nearest to or: and, than, perennially, but, yog, schala, jabbar, bissette,
# Nearest to so: imran, too, divergent, if, applications, recursive, stardust, ancestral,
# Nearest to this: it, which, that, there, stanton, the, ovule, what,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to years: days, year, times, months, decades, weeks, alomari, trebizond,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to at: turbines, in, during, ripening, upload, without, within, nameless,
# Nearest to will: would, must, can, could, may, should, might, cannot,
# Nearest to often: sometimes, usually, generally, commonly, now, frequently, widely, still,
# Nearest to four: five, eight, six, seven, three, nine, two, zero,
# Nearest to new: dials, painterly, huge, catastrophism, convenient, irrigation, federal, previous,
# Nearest to there: they, it, now, currently, he, this, still, she,
# Average loss at step 62000: 3.237582
# Average loss at step 64000: 3.255838
# Average loss at step 66000: 3.408976
# Average loss at step 68000: 3.395247
# Average loss at step 70000: 3.359425
# Nearest to all: many, both, some, every, most, receptions, those, these,
# Nearest to history: period, irwin, list, complementary, vatican, uncertainty, apollodorus, cristina,
# Nearest to from: through, into, modi, before, in, between, theistic, within,
# Nearest to system: systems, line, nisibis, cladistics, network, massif, rastafari, inquest,
# Nearest to or: and, than, yog, retribution, while, but, mates, rip,
# Nearest to so: thus, too, if, imran, sometimes, applications, before, stardust,
# Nearest to this: which, it, that, there, the, stanton, another, some,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to years: days, months, year, decades, times, weeks, hours, alomari,
# Nearest to they: we, there, he, you, it, she, amor, then,
# Nearest to at: during, turbines, upload, in, ripening, without, demoralized, interrogated,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, widely, still,
# Nearest to four: six, three, seven, five, eight, zero, two, nine,
# Nearest to new: painterly, huge, outback, dials, different, tint, distrust, previous,
# Nearest to there: they, it, now, still, we, usually, he, this,
# Average loss at step 72000: 3.371127
# Average loss at step 74000: 3.347066
# Average loss at step 76000: 3.318221
# Average loss at step 78000: 3.347142
# Average loss at step 80000: 3.377123
# Nearest to all: both, many, every, various, receptions, these, any, granny,
# Nearest to history: irwin, period, complementary, capitals, apollodorus, gico, list, dvi,
# Nearest to from: through, into, within, bukharin, in, modi, aggressors, after,
# Nearest to system: systems, inquest, program, massif, nuns, electron, line, nisibis,
# Nearest to or: and, than, while, but, xiongnu, harming, bounding, forget,
# Nearest to so: too, thus, before, if, recursive, imran, then, stardust,
# Nearest to this: which, it, another, the, that, there, stanton, none,
# Nearest to three: four, six, eight, five, seven, two, nine, zero,
# Nearest to years: days, months, weeks, year, decades, times, hours, minutes,
# Nearest to they: we, he, there, you, she, it, cnet, these,
# Nearest to at: in, during, turbines, without, superstitions, ripening, upload, seabirds,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, typically, still,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to new: outback, painterly, huge, dials, previous, pedersen, tint, old,
# Nearest to there: they, it, he, still, she, currently, usually, we,
# Average loss at step 82000: 3.403988
# Average loss at step 84000: 3.407872
# Average loss at step 86000: 3.386593
# Average loss at step 88000: 3.353143
# Average loss at step 90000: 3.364214
# Nearest to all: both, many, every, several, any, some, deduces, receptions,
# Nearest to history: period, irwin, list, vatican, complementary, philosophy, reflex, cristina,
# Nearest to from: through, into, within, during, before, under, bukharin, towards,
# Nearest to system: systems, program, unit, nuns, network, multidisciplinary, assisi, baez,
# Nearest to or: and, than, including, oise, rip, harming, cucumbers, while,
# Nearest to so: thus, if, too, before, then, imran, gangetic, stardust,
# Nearest to this: it, which, some, the, another, stanton, clustered, philosophie,
# Nearest to three: five, two, four, eight, six, seven, nine, zero,
# Nearest to years: days, months, decades, year, weeks, times, minutes, centuries,
# Nearest to they: we, he, there, she, you, it, amor, but,
# Nearest to at: during, interrogated, upper, on, demoralized, in, upload, while,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to often: sometimes, usually, commonly, generally, frequently, now, also, still,
# Nearest to four: six, five, seven, eight, three, two, nine, one,
# Nearest to new: painterly, different, outback, old, huge, maradona, steeply, hsbc,
# Nearest to there: they, it, he, she, still, we, currently, usually,
# Average loss at step 92000: 3.399123
# Average loss at step 94000: 3.249487
# Average loss at step 96000: 3.357541
# Average loss at step 98000: 3.244868
# Average loss at step 100000: 3.353479
# Nearest to all: both, every, many, some, any, several, various, these,
# Nearest to history: period, irwin, list, vatican, complementary, capitals, stereo, dvi,
# Nearest to from: through, in, into, across, affaires, during, aggressors, before,
# Nearest to system: systems, program, unit, nuns, baez, cladistics, multidisciplinary, model,
# Nearest to or: and, than, harming, while, but, hijackings, yog, without,
# Nearest to so: thus, then, too, if, recursive, ancestral, stardust, when,
# Nearest to this: which, it, the, another, some, that, astrophysicists, itself,
# Nearest to three: five, four, eight, six, seven, two, nine, zero,
# Nearest to years: days, year, months, decades, weeks, times, minutes, centuries,
# Nearest to they: we, he, there, you, she, it, i, not,
# Nearest to at: during, in, on, spooky, upload, turbines, interrogated, demoralized,
# Nearest to will: would, must, can, could, may, should, might, cannot,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, now, widely,
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Nearest to new: different, painterly, huge, masoretic, mohiam, scuba, outback, old,
# Nearest to there: they, it, he, we, still, often, usually, she,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /home/maxkhk/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from itertools import compress

# %%
#data preparation

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))

vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

#generally what we do here is build data as a pack of words to left and right of the target word
#and label is the target word

def generate_batch_cbow(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch_cbow(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  # Notice per description of CBOW we have to sum all the embedings!
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds,1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
    
    
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.095695
# Nearest to people: ecuador, visibly, contraceptives, bitstream, howell, chagrin, launcher, circumvented,
# Nearest to this: shimura, niki, squealer, tachycardia, sketchy, solubility, sheer, australis,
# Nearest to in: hotly, raions, expended, papen, lachlan, tis, calhoun, stipend,
# Nearest to of: mostar, rudolph, divert, berthold, babel, sewage, agi, antony,
# Nearest to up: parallelism, charlemagne, lysis, cavities, lughnasadh, optimized, attire, revolutionize,
# Nearest to war: metabolized, tica, hearts, downright, decried, cdg, tosses, carducci,
# Nearest to after: fmln, dictionaries, unopened, care, wolfman, firsts, miserably, catering,
# Nearest to most: disruptions, rosebud, dismissing, bavarian, rivals, kazakhstan, griffin, metrology,
# Nearest to are: nominate, adding, rebadged, handily, artifice, dagon, bactria, shoe,
# Nearest to first: hijackers, ethology, karamanlis, deng, shoots, leu, superstructure, menacing,
# Nearest to american: catalysed, lorenzo, lifecycle, porta, lugh, endeavour, admitting, secrets,
# Nearest to state: qur, devoting, lifecycle, meribbaal, mozambique, nkrumah, eyre, vci,
# Nearest to many: yourself, schistosomiasis, heinkel, mailer, conquerors, incessantly, alene, george,
# Nearest to their: criticizes, electron, saskatoon, heterosexism, tero, suicidal, guanine, polg,
# Nearest to and: muslims, mellon, cellular, injurious, tucum, subtree, complexion, culp,
# Nearest to the: megalithic, seneca, lentils, econometric, discernable, ifv, mercalli, posters,
# Average loss at step 2000: 10.281920
# Average loss at step 4000: 6.481425
# Average loss at step 6000: 5.254503
# Average loss at step 8000: 4.668232
# Average loss at step 10000: 4.196748
# Nearest to people: hypertalk, those, they, worthy, immaculate, parts, polonia, stewardship,
# Nearest to this: it, any, which, another, rolf, the, a, denominator,
# Nearest to in: during, on, beltaine, breasted, since, at, of, unfortunate,
# Nearest to of: for, in, rote, cear, dewey, infatuated, seo, longed,
# Nearest to up: charlemagne, substances, trying, mc, restrictions, unifies, wildcat, reorganized,
# Nearest to war: insignificance, eocene, mcgregor, axe, lcms, grindcore, dine, eubacteria,
# Nearest to after: during, when, emulsions, allergic, ppg, before, pondering, macy,
# Nearest to most: antonine, arizona, jarry, wall, roi, economy, play, alfred,
# Nearest to are: were, is, was, alvar, tcl, have, pohnpei, kelvins,
# Nearest to first: same, last, sophie, ignite, karamanlis, su, second, pending,
# Nearest to american: binder, balinese, fluid, sham, cordova, tracy, servile, conn,
# Nearest to state: negation, federal, iconostasis, thr, altogether, pinkerton, nkrumah, meribbaal,
# Nearest to many: some, several, various, all, concentric, these, transhuman, stadium,
# Nearest to their: its, his, our, any, the, some, her, cigarettes,
# Nearest to and: or, hubris, pluralist, chuppah, however, undertaking, mundi, ecole,
# Nearest to the: its, a, any, this, their, another, kevlar, wimp,
# Average loss at step 12000: 3.926789
# Average loss at step 14000: 3.955262
# Average loss at step 16000: 4.185083
# Average loss at step 18000: 4.426293
# Average loss at step 20000: 3.743780
# Nearest to people: those, runtime, scientists, others, abolishing, children, geothermal, them,
# Nearest to this: which, that, it, islamabad, any, tachycardia, guardia, repressions,
# Nearest to in: since, near, berlin, aragonese, capitals, steiner, on, liddell,
# Nearest to of: diss, halle, colonized, lactose, balalaika, norse, monadic, gbit,
# Nearest to up: down, them, rocketry, gundam, ffts, naming, charlemagne, bw,
# Nearest to war: berlin, auckland, aragonese, mathematics, jarry, w, steiner, roi,
# Nearest to after: before, when, during, for, denunciation, ezek, pondering, schaff,
# Nearest to most: more, many, xml, some, filings, garnering, legation, among,
# Nearest to are: were, is, was, include, have, aj, vindicated, aides,
# Nearest to first: second, same, next, sophie, graduate, last, stijl, belknap,
# Nearest to american: lair, middleware, americans, overdrive, compare, arecibo, intensified, empties,
# Nearest to state: government, federal, worship, law, iconostasis, faramir, abrogation, ergaster,
# Nearest to many: some, several, various, these, numerous, most, all, hypertalk,
# Nearest to their: his, antonine, jarry, blackwood, berlin, catalan, bdp, mathematics,
# Nearest to and: or, while, but, magee, fini, flurry, irreversibly, pollinators,
# Nearest to the: their, his, its, a, an, each, any, mobilized,
# Average loss at step 22000: 3.613316
# Average loss at step 24000: 3.457595
# Average loss at step 26000: 3.415654
# Average loss at step 28000: 3.411489
# Average loss at step 30000: 3.512093
# Nearest to people: those, players, bribes, convinces, things, perfecting, hbo, americans,
# Nearest to this: it, which, what, greats, the, that, battlefront, electrochemical,
# Nearest to in: within, since, xxxx, on, kensington, tarim, until, from,
# Nearest to of: monadic, in, lollard, ablative, contagious, dewey, including, skipping,
# Nearest to up: them, rocketry, down, charlemagne, deconvolution, bw, off, naming,
# Nearest to war: irredentist, culprits, insignificance, biggs, wars, lascaux, ideologies, continent,
# Nearest to after: before, during, for, since, following, against, through, from,
# Nearest to most: some, more, many, cautionary, all, breach, xml, majority,
# Nearest to are: is, were, include, alvar, was, aj, contain, fujitsu,
# Nearest to first: second, last, same, next, third, best, highest, clunies,
# Nearest to american: adult, computations, british, americans, classical, tray, lair, integrals,
# Nearest to state: theseus, area, angel, aragonese, dutch, upstream, berlin, shifted,
# Nearest to many: several, some, various, all, few, numerous, different, aaron,
# Nearest to their: its, his, her, our, the, your, vagaries, delicious,
# Nearest to and: while, or, but, although, including, though, secluded, barns,
# Nearest to the: its, their, our, a, this, his, gigs, her,
# Average loss at step 32000: 3.133600
# Average loss at step 34000: 3.361690
# Average loss at step 36000: 3.347207
# Average loss at step 38000: 3.382442
# Average loss at step 40000: 3.283566
# Nearest to people: those, men, things, children, stewardship, bribes, person, americans,
# Nearest to this: another, it, which, a, each, the, what, unchanging,
# Nearest to in: within, during, throughout, on, since, potters, crass, breasted,
# Nearest to of: include, within, from, monadic, throughout, balalaika, in, gbit,
# Nearest to up: off, conveniently, out, them, settling, office, rocketry, schemes,
# Nearest to war: wars, culprits, lascaux, irredentist, biggs, throats, ideologies, contesting,
# Nearest to after: anise, following, capitals, childe, christmas, aragonese, reich, thousand,
# Nearest to most: more, less, some, many, extremely, especially, best, frits,
# Nearest to are: were, is, was, include, aj, downwind, perceive, tcl,
# Nearest to first: second, last, following, original, next, third, same, final,
# Nearest to american: america, australian, prize, murdering, lair, americans, meitner, fgth,
# Nearest to state: pinkerton, city, grammaticus, exponent, radioactivity, indivisible, priscus, earthworm,
# Nearest to many: some, several, various, both, all, most, crustaceans, certain,
# Nearest to their: its, his, her, our, your, the, various, flank,
# Nearest to and: or, while, but, including, although, however, though, hoff,
# Nearest to the: a, its, hundreds, their, petra, frobisher, another, this,
# Average loss at step 42000: 3.533453
# Average loss at step 44000: 3.446233
# Average loss at step 46000: 3.670697
# Average loss at step 48000: 3.406445
# Average loss at step 50000: 3.564883
# Nearest to people: players, students, those, things, americans, person, children, men,
# Nearest to this: which, it, what, another, greats, oberon, battlefront, a,
# Nearest to in: within, throughout, during, until, where, when, partake, xxxx,
# Nearest to of: gbit, including, maximization, dewey, yukio, balalaika, for, lactose,
# Nearest to up: off, him, out, icrc, rocketry, deconvolution, forth, bw,
# Nearest to war: irredentist, wars, insignificance, biggs, ideologies, throats, surnames, submachine,
# Nearest to after: before, during, when, until, since, following, eschews, without,
# Nearest to most: more, less, many, because, some, best, incarnate, breach,
# Nearest to are: were, is, was, include, contain, aj, sundance, be,
# Nearest to first: second, next, last, third, same, best, fourth, original,
# Nearest to american: australian, empties, british, rb, servile, nih, stuffed, canadian,
# Nearest to state: redevelopment, government, city, pinkerton, junctions, california, texas, thelema,
# Nearest to many: some, several, various, all, numerous, certain, most, those,
# Nearest to their: its, his, our, your, her, the, these, certain,
# Nearest to and: or, including, while, although, though, but, magee, since,
# Nearest to the: his, its, their, a, petra, frobisher, ligaments, rsc,
# Average loss at step 52000: 3.233595
# Average loss at step 54000: 3.325691
# Average loss at step 56000: 3.075336
# Average loss at step 58000: 3.433210
# Average loss at step 60000: 3.288829
# Nearest to people: players, those, americans, peoples, worthy, marriageable, person, we,
# Nearest to this: which, it, what, another, the, repressions, a, capacitive,
# Nearest to in: within, during, throughout, since, until, among, angell, tarim,
# Nearest to of: however, thus, lasso, among, evangelion, tiamat, in, jun,
# Nearest to up: off, down, out, rocketry, specialities, reflective, back, rif,
# Nearest to war: stage, irredentist, culprits, insignificance, wars, grampus, surnames, ideologies,
# Nearest to after: before, when, during, following, afterwards, thereafter, into, within,
# Nearest to most: some, especially, many, less, extremely, melanchthon, garnering, lut,
# Nearest to are: were, is, include, was, contain, including, have, bosco,
# Nearest to first: last, second, next, final, third, best, previous, resigns,
# Nearest to american: murdering, america, canadian, australian, cordova, severly, carolina, british,
# Nearest to state: states, defense, thelema, defence, government, separation, alabama, pyrrhus,
# Nearest to many: some, several, various, numerous, particularly, few, themselves, all,
# Nearest to their: its, his, her, our, your, the, whose, my,
# Nearest to and: or, theseus, liddell, base, jarry, bdp, dollar, boundary,
# Nearest to the: a, its, our, an, their, his, rumsfeld, kansas,
# Average loss at step 62000: 3.211684
# Average loss at step 64000: 3.068096
# Average loss at step 66000: 3.069924
# Average loss at step 68000: 3.293156
# Average loss at step 70000: 3.204001
# Nearest to people: users, players, those, inhabitants, them, actors, person, sister,
# Nearest to this: another, which, it, endeavoured, main, a, conjunctions, capacitive,
# Nearest to in: during, throughout, within, since, outside, around, on, until,
# Nearest to of: throughout, for, in, posthumus, including, yukio, after, australasian,
# Nearest to up: off, rocketry, deconvolution, specialities, back, calvinistic, angkor, him,
# Nearest to war: wars, irredentist, conflict, insignificance, occupation, degradation, championship, devil,
# Nearest to after: before, during, following, when, for, afterwards, despite, from,
# Nearest to most: particularly, many, more, some, largest, especially, melanchthon, extremely,
# Nearest to are: were, is, include, including, was, have, contain, alvar,
# Nearest to first: last, second, next, third, fourth, same, final, previous,
# Nearest to american: canadian, british, tracy, australian, english, irish, vertebrate, russian,
# Nearest to state: thelema, hinged, states, alabama, government, atmosphere, oligarchy, pyrrhus,
# Nearest to many: some, several, numerous, various, all, most, both, these,
# Nearest to their: its, his, our, her, the, your, both, these,
# Nearest to and: while, or, but, although, including, however, flurry, though,
# Nearest to the: their, a, its, his, our, undamaged, an, petra,
# Average loss at step 72000: 3.060609
# Average loss at step 74000: 3.019460
# Average loss at step 76000: 3.078986
# Average loss at step 78000: 3.121032
# Average loss at step 80000: 2.922412
# Nearest to people: men, actors, persons, women, voters, those, americans, children,
# Nearest to this: which, it, endeavoured, another, a, multipurpose, main, what,
# Nearest to in: within, throughout, during, on, including, outside, through, since,
# Nearest to of: while, throughout, following, yukio, behind, balalaika, mailing, including,
# Nearest to up: off, back, rocketry, laga, out, specialities, down, deconvolution,
# Nearest to war: wars, irredentist, culprits, degradation, occupation, conflict, professorship, transvestite,
# Nearest to after: before, following, when, during, since, despite, afterwards, upon,
# Nearest to most: many, more, particularly, some, less, all, first, melanchthon,
# Nearest to are: were, is, include, was, have, exist, aj, exists,
# Nearest to first: last, next, second, same, third, fourth, previous, final,
# Nearest to american: canadian, australian, america, british, americans, irish, meitner, conn,
# Nearest to state: government, breasts, duke, states, rank, alabama, thelema, texas,
# Nearest to many: some, several, numerous, all, various, both, most, number,
# Nearest to their: its, her, his, your, our, my, the, whose,
# Nearest to and: or, while, including, but, etc, though, although, stumble,
# Nearest to the: his, their, our, a, its, any, another, an,
# Average loss at step 82000: 3.028193
# Average loss at step 84000: 2.966762
# Average loss at step 86000: 2.997606
# Average loss at step 88000: 3.025596
# Average loss at step 90000: 2.896787
# Nearest to people: men, players, persons, americans, children, individuals, those, parents,
# Nearest to this: it, another, which, what, any, a, endeavoured, milky,
# Nearest to in: throughout, within, during, since, outside, tarim, on, until,
# Nearest to of: following, including, monadic, in, balalaika, include, throughout, posthumus,
# Nearest to up: off, down, back, out, together, them, forward, him,
# Nearest to war: wars, irredentist, occupation, prs, transvestite, championship, professorship, revolution,
# Nearest to after: during, before, when, since, within, following, upon, without,
# Nearest to most: especially, plug, fetched, waving, wolfe, epiphany, ds, tia,
# Nearest to are: were, is, include, was, exist, activating, includes, have,
# Nearest to first: last, next, second, third, fourth, final, following, same,
# Nearest to american: australian, british, america, meitner, americans, canadian, saturdays, nih,
# Nearest to state: pyrrhus, government, junctions, meribbaal, states, vilas, brigadier, breasts,
# Nearest to many: some, several, various, numerous, both, all, certain, most,
# Nearest to their: its, his, our, her, your, the, my, whose,
# Nearest to and: or, but, while, although, despite, like, gan, plus,
# Nearest to the: a, its, his, their, an, another, any, our,
# Average loss at step 92000: 2.968576
# Average loss at step 94000: 2.933582
# Average loss at step 96000: 2.763381
# Average loss at step 98000: 2.493834
# Average loss at step 100000: 2.745282
# Nearest to people: players, men, americans, individuals, persons, those, children, jews,
# Nearest to this: which, another, afp, it, stabilised, capacitive, some, catullus,
# Nearest to in: within, outside, throughout, during, tarim, into, inside, at,
# Nearest to of: in, monadic, evangelion, yukio, represents, lollard, including, toward,
# Nearest to up: off, out, back, down, together, laga, rocketry, specialities,
# Nearest to war: wars, irredentist, occupation, venezuela, insignificance, ngos, grampus, revolution,
# Nearest to after: before, following, since, afterwards, despite, without, though, during,
# Nearest to most: particularly, best, more, especially, many, less, some, first,
# Nearest to are: were, is, was, include, have, exist, exists, perceive,
# Nearest to first: last, next, second, final, third, best, fourth, throughout,
# Nearest to american: english, australian, canadian, british, irish, brooker, tracy, conn,
# Nearest to state: states, texas, grudge, redevelopment, government, vilas, rank, agency,
# Nearest to many: some, several, various, numerous, both, all, hundreds, most,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to and: or, but, while, including, however, although, stumble, etc,
# Nearest to the: its, his, their, a, any, every, our, each,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /home/maxkhk/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
